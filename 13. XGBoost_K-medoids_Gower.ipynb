# %%
# FULL

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def calculate_within_tolerance(y_true, y_pred, tolerance):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    within_tolerance = np.abs(y_true - y_pred) / y_true <= tolerance
    percentage_within_tolerance = np.mean(within_tolerance) * 100
    return percentage_within_tolerance

# %%
# Load the datasets
data_path = '../13. Data from R 50000/'
X_train = pd.read_parquet(data_path + 'X_train_2024.parquet', engine='pyarrow')
X_test = pd.read_parquet(data_path + 'X_test_2024.parquet', engine='pyarrow')
seed_num = 2024

# Load y_train and y_test
y_train = pd.read_parquet(data_path + 'y_train_2024.parquet').iloc[:, 0]
y_test = pd.read_parquet(data_path + 'y_test_2024.parquet').iloc[:, 0]

# List of categorical variables
categorical_vars = [
    "MARITALSTATUS", "NOOFCHILDREN", "HOMEOWNERIND", "VEHICLE_LEFTORRIGHTHANDDRIVE",
    "DRIVER1_LICENCETYPE", "DRIVER2_LICENCETYPE", "DRIVER3_LICENCETYPE", "DRIVER4_LICENCETYPE",
    "DRIVER1_OTHERVEHICLEOWNEDIND", "DRIVER2_OTHERVEHICLEOWNEDIND", "DRIVER3_OTHERVEHICLEOWNEDIND",
    "DRIVER4_OTHERVEHICLEOWNEDIND", "MONTHLYPAYMENTSIND", "VEHICLE_USE_TYPE", "VEHICLEOVERNIGHTLOCATION",
    "VEHICLE_OWNERSHIP", "VEHICLE_MODIFIEDIND", "VEHICLE_BODYTYPE", "VEHICLE_FUELTYPE",
    "VEHICLE_TRANSMISSIONTYPE", "INDICATOR_NRCONVICTIONS_RECENT", "INDICATOR_CLAIMSCOUNT_RECENT"
]

# Define numerical columns by excluding categorical ones
numerical_vars = [col for col in X_train.columns if col not in categorical_vars]

# Dictionaries to store models, predictions, errors, and subset sizes
model_store = {}
prediction_store = {}
errors_store = {}
subset_sizes = {}

# Initialize lists to store the combined true values and predictions across all datasets
all_y_test_global = []
all_y_pred_global = []

# Function to calculate percentage within tolerance
def calculate_within_tolerance(y_true, y_pred, tolerance):
    within_tolerance = abs(y_true - y_pred) / y_true <= tolerance
    percentage_within_tolerance = within_tolerance.mean() * 100
    return percentage_within_tolerance

# Processing datasets
for i in range(2, 11):  # Loop from 2 to 10 clusters
    X_train_additional = pd.read_parquet(f'{data_path}X_train_skm_gower_c{i}_seed_2024.parquet')
    X_test_additional = pd.read_parquet(f'{data_path}X_test_skm_gower_c{i}_seed_2024.parquet')
    
    # Append the last columns to the main datasets
    X_train[f'additional_feature_{i}'] = X_train_additional.iloc[:, -1]
    X_test[f'additional_feature_{i}'] = X_test_additional.iloc[:, -1]

    # Initialize error storage for this dataset
    errors_store[i] = {}
    subset_sizes[i] = {}
    
    # Unique values in the 'additional_feature' column
    unique_values = X_train[f'additional_feature_{i}'].unique()

    # Initialize lists to store the combined true values and predictions for this dataset
    dataset_y_test = []
    dataset_y_pred = []
    
    # Initialize metrics lists
    mse_list = []
    mae_list = []
    rmse_list = []
    mape_list = []
    rmspe_list = []
    r2_list = []
    segment_sizes = []

    for value in unique_values:
        # Split the data by 'additional_feature'
        X_train_subset = X_train[X_train[f'additional_feature_{i}'] == value]
        X_test_subset = X_test[X_test[f'additional_feature_{i}'] == value]
        y_train_subset = y_train[X_train[f'additional_feature_{i}'] == value]
        y_test_subset = y_test[X_test[f'additional_feature_{i}'] == value]

        # Initialize and train the XGBoost model
        model = XGBRegressor(random_state=2024)
        model.fit(X_train_subset.drop(columns=[f'additional_feature_{i}']), y_train_subset)
        model_store[(i, value)] = model

        # Predict on the corresponding test set
        y_pred_subset = model.predict(X_test_subset.drop(columns=[f'additional_feature_{i}']))
        prediction_store[(i, value)] = y_pred_subset

        # Combine predictions and true values for this dataset
        dataset_y_test.extend(y_test_subset.tolist())
        dataset_y_pred.extend(y_pred_subset.tolist())

        # Calculate metrics for this subset
        mse = mean_squared_error(y_test_subset, y_pred_subset)
        mae = mean_absolute_error(y_test_subset, y_pred_subset)
        rmse = np.sqrt(mse)
        mape = np.mean(np.abs((y_test_subset - y_pred_subset) / y_test_subset)) * 100
        rmspe = np.sqrt(np.mean(np.square((y_test_subset - y_pred_subset) / y_test_subset))) * 100
        r2 = r2_score(y_test_subset, y_pred_subset)

        # Store differences for plotting
        differences = y_pred_subset - y_test_subset
        errors_store[i][value] = differences
        subset_sizes[i][value] = len(y_test_subset)
        
        # Append metrics and segment size to lists
        mse_list.append(mse)
        mae_list.append(mae)
        rmse_list.append(rmse)
        mape_list.append(mape)
        rmspe_list.append(rmspe)
        r2_list.append(r2)
        segment_sizes.append(len(y_test_subset))

        # Print metrics for each subset
        print(f"Dataset {i}, Value {value}:")
        print(f"  MSE: {mse:.2f}")
        print(f"  MAE: {mae:.2f}")
        print(f"  RMSE: {rmse:.2f}")
        print(f"  MAPE: {mape:.2f}%")
        print(f"  RMSPE: {rmspe:.2f}%")
        print(f"  R^2: {r2:.2f}")

    # Convert combined lists to numpy arrays for overall evaluation for this dataset
    dataset_y_test = np.array(dataset_y_test)
    dataset_y_pred = np.array(dataset_y_pred)

    # Combine the current dataset predictions with the global lists
    all_y_test_global.extend(dataset_y_test)
    all_y_pred_global.extend(dataset_y_pred)

    # Calculate overall metrics for the current dataset
    overall_mse = mean_squared_error(dataset_y_test, dataset_y_pred)
    overall_mae = mean_absolute_error(dataset_y_test, dataset_y_pred)
    overall_rmse = np.sqrt(overall_mse)
    overall_mape = np.mean(np.abs((dataset_y_test - dataset_y_pred) / dataset_y_test)) * 100
    overall_rmspe = np.sqrt(np.mean(np.square((dataset_y_test - dataset_y_pred) / dataset_y_test))) * 100
    overall_r2 = r2_score(dataset_y_test, dataset_y_pred)

    # Calculate percentage within tolerance for the current dataset
    overall_within_10 = calculate_within_tolerance(dataset_y_test, dataset_y_pred, 0.10)
    overall_within_50 = calculate_within_tolerance(dataset_y_test, dataset_y_pred, 0.50)
    overall_within_100 = calculate_within_tolerance(dataset_y_test, dataset_y_pred, 1.00)

    # Add overall dataset differences for plotting (optional)
    errors_store[i]['overall'] = dataset_y_pred - dataset_y_test

    # Display overall metrics for the current dataset
    print(f"\nOverall Metrics for Dataset {i}:")
    print(f"  MSE: {overall_mse:.2f}")
    print(f"  MAE: {overall_mae:.2f}")
    print(f"  RMSE: {overall_rmse:.2f}")
    print(f"  MAPE: {overall_mape:.2f}%")
    print(f"  RMSPE: {overall_rmspe:.2f}%")
    print(f"  R^2: {overall_r2:.2f}")
    print(f"  Percentage within 10%: {overall_within_10:.2f}%")
    print(f"  Percentage within 50%: {overall_within_50:.2f}%")
    print(f"  Percentage within 100%: {overall_within_100:.2f}%")

# Plotting density curves of prediction errors for each dataset
for i in errors_store:
    plt.figure(figsize=(12, 8))
    for value, errors in errors_store[i].items():
        if value == 'overall':
            sns.kdeplot(errors, label=f'Overall Dataset {i}', linewidth=2.5)
        else:
            sns.kdeplot(errors, label=f'Value {value} (n={subset_sizes[i][value]})')
    plt.title(f'Density Plot of Prediction Errors for Dataset {i}')
    plt.xlabel('Prediction Error')
    plt.ylabel('Density')
    plt.legend()
    plt.show()
# Out:
# Dataset 2, Value 2:
#   MSE: 143397.75
#   MAE: 274.87
#   RMSE: 378.68
#   MAPE: 24.84%
#   RMSPE: 37.09%
#   R^2: 0.71
# Dataset 2, Value 1:
#   MSE: 57439.63
#   MAE: 147.46
#   RMSE: 239.67
#   MAPE: 21.76%
#   RMSPE: 30.41%
#   R^2: 0.75
#
# Overall Metrics for Dataset 2:
#   MSE: 97040.54
#   MAE: 206.16
#   RMSE: 311.51
#   MAPE: 23.18%
#   RMSPE: 33.65%
#   R^2: 0.78
#   Percentage within 10%: 32.87%
#   Percentage within 50%: 90.12%
#   Percentage within 100%: 98.51%
# Dataset 3, Value 1:
#   MSE: 137769.81
#   MAE: 261.15
#   RMSE: 371.17
#   MAPE: 22.55%
#   RMSPE: 33.33%
#   R^2: 0.73
# Dataset 3, Value 2:
#   MSE: 134423.71
#   MAE: 262.70
#   RMSE: 366.64
#   MAPE: 25.61%
#   RMSPE: 36.79%
#   R^2: 0.69
# Dataset 3, Value 3:
#   MSE: 40911.67
#   MAE: 123.04
#   RMSE: 202.27
#   MAPE: 20.81%
#   RMSPE: 28.94%
#   R^2: 0.74
#
# Overall Metrics for Dataset 3:
#   MSE: 96498.49
#   MAE: 204.42
#   RMSE: 310.64
#   MAPE: 22.86%
#   RMSPE: 32.85%
#   R^2: 0.78
#   Percentage within 10%: 33.33%
#   Percentage within 50%: 90.55%
#   Percentage within 100%: 98.46%
# Dataset 4, Value 1:
#   MSE: 136677.90
#   MAE: 259.04
#   RMSE: 369.70
#   MAPE: 22.87%
#   RMSPE: 33.95%
#   R^2: 0.74
# Dataset 4, Value 2:
#   MSE: 130383.03
#   MAE: 257.10
#   RMSE: 361.09
#   MAPE: 25.00%
#   RMSPE: 37.00%
#   R^2: 0.70
# Dataset 4, Value 4:
#   MSE: 70071.41
#   MAE: 167.79
#   RMSE: 264.71
#   MAPE: 21.34%
#   RMSPE: 31.46%
#   R^2: 0.69
# Dataset 4, Value 3:
#   MSE: 38417.37
#   MAE: 111.20
#   RMSE: 196.00
#   MAPE: 21.15%
#   RMSPE: 29.82%
#   R^2: 0.72
#
# Overall Metrics for Dataset 4:
#   MSE: 97085.34
#   MAE: 203.58
#   RMSE: 311.59
#   MAPE: 22.79%
#   RMSPE: 33.49%
#   R^2: 0.78
#   Percentage within 10%: 34.12%
#   Percentage within 50%: 90.32%
#   Percentage within 100%: 98.28%
# Dataset 5, Value 1:
#   MSE: 138271.41
#   MAE: 260.21
#   RMSE: 371.85
#   MAPE: 22.27%
#   RMSPE: 33.26%
#   R^2: 0.74
# Dataset 5, Value 2:
#   MSE: 151947.08
#   MAE: 286.94
#   RMSE: 389.80
#   MAPE: 25.29%
#   RMSPE: 38.32%
#   R^2: 0.66
# Dataset 5, Value 3:
#   MSE: 72410.97
#   MAE: 169.35
#   RMSE: 269.09
#   MAPE: 22.35%
#   RMSPE: 33.32%
#   R^2: 0.65
# Dataset 5, Value 5:
#   MSE: 42207.34
#   MAE: 112.73
#   RMSE: 205.44
#   MAPE: 20.81%
#   RMSPE: 31.43%
#   R^2: 0.75
# Dataset 5, Value 4:
#   MSE: 49396.11
#   MAE: 138.95
#   RMSE: 222.25
#   MAPE: 22.15%
#   RMSPE: 31.55%
#   R^2: 0.62
#
# Overall Metrics for Dataset 5:
#   MSE: 97666.89
#   MAE: 203.53
#   RMSE: 312.52
#   MAPE: 22.72%
#   RMSPE: 33.98%
#   R^2: 0.78
#   Percentage within 10%: 35.22%
#   Percentage within 50%: 90.43%
#   Percentage within 100%: 98.16%
# Dataset 6, Value 1:
#   MSE: 147582.41
#   MAE: 268.39
#   RMSE: 384.16
#   MAPE: 23.62%
#   RMSPE: 35.91%
#   R^2: 0.72
# Dataset 6, Value 5:
#   MSE: 153527.00
#   MAE: 286.92
#   RMSE: 391.83
#   MAPE: 24.91%
#   RMSPE: 36.43%
#   R^2: 0.65
# Dataset 6, Value 2:
#   MSE: 67418.21
#   MAE: 164.46
#   RMSE: 259.65
#   MAPE: 22.00%
#   RMSPE: 32.07%
#   R^2: 0.69
# Dataset 6, Value 3:
#   MSE: 34397.19
#   MAE: 106.05
#   RMSE: 185.46
#   MAPE: 21.11%
#   RMSPE: 30.41%
#   R^2: 0.74
# Dataset 6, Value 4:
#   MSE: 137218.35
#   MAE: 254.40
#   RMSE: 370.43
#   MAPE: 21.65%
#   RMSPE: 33.89%
#   R^2: 0.74
# Dataset 6, Value 6:
#   MSE: 50316.06
#   MAE: 139.08
#   RMSE: 224.31
#   MAPE: 22.41%
#   RMSPE: 32.19%
#   R^2: 0.61
#
# Overall Metrics for Dataset 6:
#   MSE: 98292.85
#   MAE: 203.97
#   RMSE: 313.52
#   MAPE: 22.82%
#   RMSPE: 33.67%
#   R^2: 0.78
#   Percentage within 10%: 34.87%
#   Percentage within 50%: 89.99%
#   Percentage within 100%: 98.21%
# Dataset 7, Value 1:
#   MSE: 132806.48
#   MAE: 256.42
#   RMSE: 364.43
#   MAPE: 23.42%
#   RMSPE: 35.11%
#   R^2: 0.75
# Dataset 7, Value 6:
#   MSE: 147714.56
#   MAE: 281.38
#   RMSE: 384.34
#   MAPE: 24.86%
#   RMSPE: 36.78%
#   R^2: 0.67
# Dataset 7, Value 7:
#   MSE: 63758.43
#   MAE: 143.66
#   RMSE: 252.50
#   MAPE: 22.38%
#   RMSPE: 32.61%
#   R^2: 0.68
# Dataset 7, Value 4:
#   MSE: 17412.72
#   MAE: 82.61
#   RMSE: 131.96
#   MAPE: 18.12%
#   RMSPE: 25.94%
#   R^2: 0.81
# Dataset 7, Value 5:
#   MSE: 144269.03
#   MAE: 256.64
#   RMSE: 379.83
#   MAPE: 21.99%
#   RMSPE: 34.76%
#   R^2: 0.74
# Dataset 7, Value 3:
#   MSE: 47138.64
#   MAE: 131.27
#   RMSE: 217.11
#   MAPE: 21.98%
#   RMSPE: 32.36%
#   R^2: 0.61
# Dataset 7, Value 2:
#   MSE: 80403.16
#   MAE: 174.84
#   RMSE: 283.55
#   MAPE: 20.46%
#   RMSPE: 31.37%
#   R^2: 0.67
#
# Overall Metrics for Dataset 7:
#   MSE: 95842.11
#   MAE: 198.86
#   RMSE: 309.58
#   MAPE: 22.31%
#   RMSPE: 33.39%
#   R^2: 0.78
#   Percentage within 10%: 37.22%
#   Percentage within 50%: 90.20%
#   Percentage within 100%: 98.19%
# Dataset 8, Value 1:
#   MSE: 150864.80
#   MAE: 269.59
#   RMSE: 388.41
#   MAPE: 23.57%
#   RMSPE: 36.47%
#   R^2: 0.71
# Dataset 8, Value 8:
#   MSE: 160370.72
#   MAE: 282.92
#   RMSE: 400.46
#   MAPE: 25.40%
#   RMSPE: 42.45%
#   R^2: 0.63
# Dataset 8, Value 2:
#   MSE: 68253.27
#   MAE: 161.93
#   RMSE: 261.25
#   MAPE: 22.75%
#   RMSPE: 33.95%
#   R^2: 0.69
# Dataset 8, Value 4:
#   MSE: 20982.02
#   MAE: 81.33
#   RMSE: 144.85
#   MAPE: 17.52%
#   RMSPE: 25.38%
#   R^2: 0.78
# Dataset 8, Value 5:
#   MSE: 147085.09
#   MAE: 265.68
#   RMSE: 383.52
#   MAPE: 22.60%
#   RMSPE: 34.87%
#   R^2: 0.73
# Dataset 8, Value 3:
#   MSE: 135034.36
#   MAE: 261.57
#   RMSE: 367.47
#   MAPE: 25.33%
#   RMSPE: 39.35%
#   R^2: 0.69
# Dataset 8, Value 7:
#   MSE: 44062.11
#   MAE: 123.57
#   RMSE: 209.91
#   MAPE: 22.94%
#   RMSPE: 34.64%
#   R^2: 0.55
# Dataset 8, Value 6:
#   MSE: 52443.76
#   MAE: 138.66
#   RMSE: 229.01
#   MAPE: 20.22%
#   RMSPE: 29.88%
#   R^2: 0.73
#
# Overall Metrics for Dataset 8:
#   MSE: 99556.72
#   MAE: 202.40
#   RMSE: 315.53
#   MAPE: 22.85%
#   RMSPE: 35.37%
#   R^2: 0.77
#   Percentage within 10%: 37.39%
#   Percentage within 50%: 89.67%
#   Percentage within 100%: 97.85%
# Dataset 9, Value 1:
#   MSE: 107811.35
#   MAE: 218.69
#   RMSE: 328.35
#   MAPE: 21.29%
#   RMSPE: 32.77%
#   R^2: 0.77
# Dataset 9, Value 8:
#   MSE: 146843.37
#   MAE: 274.09
#   RMSE: 383.20
#   MAPE: 24.81%
#   RMSPE: 37.92%
#   R^2: 0.62
# Dataset 9, Value 3:
#   MSE: 65161.28
#   MAE: 161.30
#   RMSE: 255.27
#   MAPE: 20.70%
#   RMSPE: 30.58%
#   R^2: 0.69
# Dataset 9, Value 9:
#   MSE: 23484.27
#   MAE: 90.71
#   RMSE: 153.25
#   MAPE: 18.93%
#   RMSPE: 27.90%
#   R^2: 0.74
# Dataset 9, Value 5:
#   MSE: 46150.50
#   MAE: 112.81
#   RMSE: 214.83
#   MAPE: 21.41%
#   RMSPE: 32.37%
#   R^2: 0.72
# Dataset 9, Value 7:
#   MSE: 151432.03
#   MAE: 260.74
#   RMSE: 389.14
#   MAPE: 22.21%
#   RMSPE: 35.65%
#   R^2: 0.71
# Dataset 9, Value 2:
#   MSE: 141860.35
#   MAE: 257.73
#   RMSE: 376.64
#   MAPE: 25.11%
#   RMSPE: 39.36%
#   R^2: 0.70
# Dataset 9, Value 4:
#   MSE: 45839.72
#   MAE: 127.50
#   RMSE: 214.10
#   MAPE: 22.62%
#   RMSPE: 32.71%
#   R^2: 0.61
# Dataset 9, Value 6:
#   MSE: 154313.97
#   MAE: 276.48
#   RMSE: 392.83
#   MAPE: 23.93%
#   RMSPE: 36.68%
#   R^2: 0.71
#
# Overall Metrics for Dataset 9:
#   MSE: 99252.79
#   MAE: 200.23
#   RMSE: 315.04
#   MAPE: 22.52%
#   RMSPE: 34.44%
#   R^2: 0.77
#   Percentage within 10%: 37.82%
#   Percentage within 50%: 89.68%
#   Percentage within 100%: 97.93%
# Dataset 10, Value 1:
#   MSE: 150638.09
#   MAE: 272.66
#   RMSE: 388.12
#   MAPE: 22.77%
#   RMSPE: 35.00%
#   R^2: 0.71
# Dataset 10, Value 2:
#   MSE: 147374.72
#   MAE: 276.91
#   RMSE: 383.89
#   MAPE: 24.40%
#   RMSPE: 37.95%
#   R^2: 0.66
# Dataset 10, Value 8:
#   MSE: 69901.70
#   MAE: 157.91
#   RMSE: 264.39
#   MAPE: 23.51%
#   RMSPE: 33.73%
#   R^2: 0.61
# Dataset 10, Value 3:
#   MSE: 86780.09
#   MAE: 175.13
#   RMSE: 294.58
#   MAPE: 23.73%
#   RMSPE: 37.67%
#   R^2: 0.62
# Dataset 10, Value 10:
#   MSE: 48271.27
#   MAE: 133.41
#   RMSE: 219.71
#   MAPE: 20.64%
#   RMSPE: 31.18%
#   R^2: 0.72
# Dataset 10, Value 6:
#   MSE: 21425.02
#   MAE: 85.63
#   RMSE: 146.37
#   MAPE: 17.98%
#   RMSPE: 26.10%
#   R^2: 0.75
# Dataset 10, Value 4:
#   MSE: 37441.25
#   MAE: 106.41
#   RMSE: 193.50
#   MAPE: 21.34%
#   RMSPE: 31.25%
#   R^2: 0.74
# Dataset 10, Value 9:
#   MSE: 149001.56
#   MAE: 265.22
#   RMSE: 386.01
#   MAPE: 22.21%
#   RMSPE: 33.79%
#   R^2: 0.72
# Dataset 10, Value 5:
#   MSE: 75014.34
#   MAE: 172.92
#   RMSE: 273.89
#   MAPE: 20.21%
#   RMSPE: 29.17%
#   R^2: 0.68
# Dataset 10, Value 7:
#   MSE: 132000.46
#   MAE: 250.52
#   RMSE: 363.32
#   MAPE: 24.45%
#   RMSPE: 37.75%
#   R^2: 0.71
#
# Overall Metrics for Dataset 10:
#   MSE: 99869.84
#   MAE: 201.42
#   RMSE: 316.02
#   MAPE: 22.49%
#   RMSPE: 34.21%
#   R^2: 0.77
#   Percentage within 10%: 37.80%
#   Percentage within 50%: 89.72%
#   Percentage within 100%: 98.16%
