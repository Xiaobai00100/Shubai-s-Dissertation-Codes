# %%
# FULL

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def calculate_within_tolerance(y_true, y_pred, tolerance):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    within_tolerance = np.abs(y_true - y_pred) / y_true <= tolerance
    percentage_within_tolerance = np.mean(within_tolerance) * 100
    return percentage_within_tolerance

# %%
# Load the datasets
data_path = '../13. Data from R 50000/'
X_train = pd.read_parquet(data_path + 'X_train_2024.parquet', engine='pyarrow')
X_test = pd.read_parquet(data_path + 'X_test_2024.parquet', engine='pyarrow')
seed_num = 2024

# Load y_train and y_test
y_train = pd.read_parquet(data_path + 'y_train_2024.parquet').iloc[:, 0]
y_test = pd.read_parquet(data_path + 'y_test_2024.parquet').iloc[:, 0]

# List of categorical variables
categorical_vars = [
    "MARITALSTATUS", "NOOFCHILDREN", "HOMEOWNERIND", "VEHICLE_LEFTORRIGHTHANDDRIVE",
    "DRIVER1_LICENCETYPE", "DRIVER2_LICENCETYPE", "DRIVER3_LICENCETYPE", "DRIVER4_LICENCETYPE",
    "DRIVER1_OTHERVEHICLEOWNEDIND", "DRIVER2_OTHERVEHICLEOWNEDIND", "DRIVER3_OTHERVEHICLEOWNEDIND",
    "DRIVER4_OTHERVEHICLEOWNEDIND", "MONTHLYPAYMENTSIND", "VEHICLE_USE_TYPE", "VEHICLEOVERNIGHTLOCATION",
    "VEHICLE_OWNERSHIP", "VEHICLE_MODIFIEDIND", "VEHICLE_BODYTYPE", "VEHICLE_FUELTYPE",
    "VEHICLE_TRANSMISSIONTYPE", "INDICATOR_NRCONVICTIONS_RECENT", "INDICATOR_CLAIMSCOUNT_RECENT"
]

# Define numerical columns by excluding categorical ones
numerical_vars = [col for col in X_train.columns if col not in categorical_vars]

# Dictionaries to store models, predictions, errors, and subset sizes
model_store = {}
prediction_store = {}
errors_store = {}
subset_sizes = {}

# Initialize lists to store the combined true values and predictions across all datasets
all_y_test_global = []
all_y_pred_global = []

# Function to calculate percentage within tolerance
def calculate_within_tolerance(y_true, y_pred, tolerance):
    within_tolerance = abs(y_true - y_pred) / y_true <= tolerance
    percentage_within_tolerance = within_tolerance.mean() * 100
    return percentage_within_tolerance

# Processing datasets
for i in range(2, 16):  # Loop from 2 to 10 clusters
    X_train_additional = pd.read_parquet(f'{data_path}X_train_kamila_c{i}_seed_2024.parquet')
    X_test_additional = pd.read_parquet(f'{data_path}X_test_kamila_c{i}_seed_2024.parquet')
    
    # Append the last columns to the main datasets
    X_train[f'additional_feature_{i}'] = X_train_additional.iloc[:, -1]
    X_test[f'additional_feature_{i}'] = X_test_additional.iloc[:, -1]

    # Initialize error storage for this dataset
    errors_store[i] = {}
    subset_sizes[i] = {}
    
    # Unique values in the 'additional_feature' column
    unique_values = X_train[f'additional_feature_{i}'].unique()

    # Initialize lists to store the combined true values and predictions for this dataset
    dataset_y_test = []
    dataset_y_pred = []
    
    # Initialize metrics lists
    mse_list = []
    mae_list = []
    rmse_list = []
    mape_list = []
    rmspe_list = []
    r2_list = []
    segment_sizes = []

    for value in unique_values:
        # Split the data by 'additional_feature'
        X_train_subset = X_train[X_train[f'additional_feature_{i}'] == value]
        X_test_subset = X_test[X_test[f'additional_feature_{i}'] == value]
        y_train_subset = y_train[X_train[f'additional_feature_{i}'] == value]
        y_test_subset = y_test[X_test[f'additional_feature_{i}'] == value]
        
        # Skip if the subset is empty
        if X_train_subset.empty or X_test_subset.empty or y_train_subset.empty or y_test_subset.empty:
            print(f"Skipping value {value} for dataset {i} due to empty subset.")
            continue

        # Initialize and train the XGBoost model
        model = XGBRegressor(random_state=2024)
        model.fit(X_train_subset.drop(columns=[f'additional_feature_{i}']), y_train_subset)
        model_store[(i, value)] = model

        # Predict on the corresponding test set
        y_pred_subset = model.predict(X_test_subset.drop(columns=[f'additional_feature_{i}']))
        prediction_store[(i, value)] = y_pred_subset

        # Combine predictions and true values for this dataset
        dataset_y_test.extend(y_test_subset.tolist())
        dataset_y_pred.extend(y_pred_subset.tolist())

        # Calculate metrics for this subset
        mse = mean_squared_error(y_test_subset, y_pred_subset)
        mae = mean_absolute_error(y_test_subset, y_pred_subset)
        rmse = np.sqrt(mse)
        mape = np.mean(np.abs((y_test_subset - y_pred_subset) / y_test_subset)) * 100
        rmspe = np.sqrt(np.mean(np.square((y_test_subset - y_pred_subset) / y_test_subset))) * 100
        r2 = r2_score(y_test_subset, y_pred_subset)

        # Store differences for plotting
        differences = y_pred_subset - y_test_subset
        errors_store[i][value] = differences
        subset_sizes[i][value] = len(y_test_subset)
        
        # Append metrics and segment size to lists
        mse_list.append(mse)
        mae_list.append(mae)
        rmse_list.append(rmse)
        mape_list.append(mape)
        rmspe_list.append(rmspe)
        r2_list.append(r2)
        segment_sizes.append(len(y_test_subset))

        # Print metrics for each subset
        print(f"Dataset {i}, Value {value}:")
        print(f"  MSE: {mse:.2f}")
        print(f"  MAE: {mae:.2f}")
        print(f"  RMSE: {rmse:.2f}")
        print(f"  MAPE: {mape:.2f}%")
        print(f"  RMSPE: {rmspe:.2f}%")
        print(f"  R^2: {r2:.2f}")

    # Convert combined lists to numpy arrays for overall evaluation for this dataset
    dataset_y_test = np.array(dataset_y_test)
    dataset_y_pred = np.array(dataset_y_pred)

    # Combine the current dataset predictions with the global lists
    all_y_test_global.extend(dataset_y_test)
    all_y_pred_global.extend(dataset_y_pred)

    # Calculate overall metrics for the current dataset
    overall_mse = mean_squared_error(dataset_y_test, dataset_y_pred)
    overall_mae = mean_absolute_error(dataset_y_test, dataset_y_pred)
    overall_rmse = np.sqrt(overall_mse)
    overall_mape = np.mean(np.abs((dataset_y_test - dataset_y_pred) / dataset_y_test)) * 100
    overall_rmspe = np.sqrt(np.mean(np.square((dataset_y_test - dataset_y_pred) / dataset_y_test))) * 100
    overall_r2 = r2_score(dataset_y_test, dataset_y_pred)

    # Calculate percentage within tolerance for the current dataset
    overall_within_10 = calculate_within_tolerance(dataset_y_test, dataset_y_pred, 0.10)
    overall_within_50 = calculate_within_tolerance(dataset_y_test, dataset_y_pred, 0.50)
    overall_within_100 = calculate_within_tolerance(dataset_y_test, dataset_y_pred, 1.00)

    # Add overall dataset differences for plotting (optional)
    errors_store[i]['overall'] = dataset_y_pred - dataset_y_test

    # Display overall metrics for the current dataset
    print(f"\nOverall Metrics for Dataset {i}:")
    print(f"  MSE: {overall_mse:.2f}")
    print(f"  MAE: {overall_mae:.2f}")
    print(f"  RMSE: {overall_rmse:.2f}")
    print(f"  MAPE: {overall_mape:.2f}%")
    print(f"  RMSPE: {overall_rmspe:.2f}%")
    print(f"  R^2: {overall_r2:.2f}")
    print(f"  Percentage within 10%: {overall_within_10:.2f}%")
    print(f"  Percentage within 50%: {overall_within_50:.2f}%")
    print(f"  Percentage within 100%: {overall_within_100:.2f}%")

# Plotting density curves of prediction errors for each dataset
for i in errors_store:
    plt.figure(figsize=(12, 8))
    for value, errors in errors_store[i].items():
        if value == 'overall':
            sns.kdeplot(errors, label=f'Overall Dataset {i}', linewidth=2.5)
        else:
            sns.kdeplot(errors, label=f'Value {value} (n={subset_sizes[i][value]})')
    plt.title(f'Density Plot of Prediction Errors for Dataset {i}')
    plt.xlabel('Prediction Error')
    plt.ylabel('Density')
    plt.legend()
    plt.show()
# Out:
# Dataset 2, Value 1.0:
#   MSE: 132107.57
#   MAE: 259.79
#   RMSE: 363.47
#   MAPE: 24.71%
#   RMSPE: 35.13%
#   R^2: 0.72
# Dataset 2, Value 2.0:
#   MSE: 34738.44
#   MAE: 112.19
#   RMSE: 186.38
#   MAPE: 20.54%
#   RMSPE: 28.70%
#   R^2: 0.71
#
# Overall Metrics for Dataset 2:
#   MSE: 98807.33
#   MAE: 209.31
#   RMSE: 314.34
#   MAPE: 23.28%
#   RMSPE: 33.07%
#   R^2: 0.78
#   Percentage within 10%: 31.59%
#   Percentage within 50%: 90.14%
#   Percentage within 100%: 98.36%
# Dataset 3, Value 1.0:
#   MSE: 120554.58
#   MAE: 244.65
#   RMSE: 347.21
#   MAPE: 24.63%
#   RMSPE: 36.30%
#   R^2: 0.70
# Dataset 3, Value 3.0:
#   MSE: 138939.56
#   MAE: 262.46
#   RMSE: 372.75
#   MAPE: 24.19%
#   RMSPE: 35.65%
#   R^2: 0.75
# Dataset 3, Value 2.0:
#   MSE: 28621.48
#   MAE: 103.51
#   RMSE: 169.18
#   MAPE: 19.67%
#   RMSPE: 27.05%
#   R^2: 0.70
#
# Overall Metrics for Dataset 3:
#   MSE: 96576.17
#   MAE: 205.21
#   RMSE: 310.77
#   MAPE: 22.97%
#   RMSPE: 33.52%
#   R^2: 0.78
#   Percentage within 10%: 33.28%
#   Percentage within 50%: 90.50%
#   Percentage within 100%: 98.18%
# Dataset 4, Value 2.0:
#   MSE: 110131.17
#   MAE: 221.86
#   RMSE: 331.86
#   MAPE: 22.96%
#   RMSPE: 32.99%
#   R^2: 0.75
# Dataset 4, Value 4.0:
#   MSE: 136938.08
#   MAE: 268.87
#   RMSE: 370.05
#   MAPE: 25.44%
#   RMSPE: 38.01%
#   R^2: 0.72
# Dataset 4, Value 3.0:
#   MSE: 24862.09
#   MAE: 94.84
#   RMSE: 157.68
#   MAPE: 19.48%
#   RMSPE: 27.48%
#   R^2: 0.68
# Dataset 4, Value 1.0:
#   MSE: 118986.48
#   MAE: 224.74
#   RMSE: 344.94
#   MAPE: 24.20%
#   RMSPE: 35.14%
#   R^2: 0.64
#
# Overall Metrics for Dataset 4:
#   MSE: 99077.42
#   MAE: 206.52
#   RMSE: 314.77
#   MAPE: 23.04%
#   RMSPE: 33.72%
#   R^2: 0.78
#   Percentage within 10%: 34.01%
#   Percentage within 50%: 90.11%
#   Percentage within 100%: 98.25%
# Dataset 5, Value 1.0:
#   MSE: 118289.33
#   MAE: 239.39
#   RMSE: 343.93
#   MAPE: 24.50%
#   RMSPE: 36.94%
#   R^2: 0.72
# Dataset 5, Value 5.0:
#   MSE: 146971.91
#   MAE: 270.14
#   RMSE: 383.37
#   MAPE: 24.13%
#   RMSPE: 35.67%
#   R^2: 0.74
# Dataset 5, Value 4.0:
#   MSE: 25418.15
#   MAE: 98.77
#   RMSE: 159.43
#   MAPE: 19.78%
#   RMSPE: 27.68%
#   R^2: 0.69
# Dataset 5, Value 2.0:
#   MSE: 168179.38
#   MAE: 268.19
#   RMSE: 410.10
#   MAPE: 29.17%
#   RMSPE: 46.00%
#   R^2: 0.56
# Dataset 5, Value 3.0:
#   MSE: 113776.63
#   MAE: 222.19
#   RMSE: 337.31
#   MAPE: 24.14%
#   RMSPE: 35.31%
#   R^2: 0.64
#
# Overall Metrics for Dataset 5:
#   MSE: 99512.34
#   MAE: 206.17
#   RMSE: 315.46
#   MAPE: 23.16%
#   RMSPE: 34.37%
#   R^2: 0.77
#   Percentage within 10%: 34.44%
#   Percentage within 50%: 89.72%
#   Percentage within 100%: 98.23%
# Dataset 6, Value 4.0:
#   MSE: 115917.58
#   MAE: 231.90
#   RMSE: 340.47
#   MAPE: 23.41%
#   RMSPE: 33.24%
#   R^2: 0.77
# Dataset 6, Value 3.0:
#   MSE: 133074.90
#   MAE: 260.95
#   RMSE: 364.79
#   MAPE: 24.93%
#   RMSPE: 36.99%
#   R^2: 0.70
# Dataset 6, Value 1.0:
#   MSE: 22491.76
#   MAE: 93.83
#   RMSE: 149.97
#   MAPE: 19.14%
#   RMSPE: 26.48%
#   R^2: 0.69
# Dataset 6, Value 2.0:
#   MSE: 143578.90
#   MAE: 254.52
#   RMSE: 378.92
#   MAPE: 28.33%
#   RMSPE: 46.84%
#   R^2: 0.64
# Dataset 6, Value 5.0:
#   MSE: 114131.28
#   MAE: 218.44
#   RMSE: 337.83
#   MAPE: 23.94%
#   RMSPE: 35.23%
#   R^2: 0.63
# Dataset 6, Value 6.0:
#   MSE: 169941.30
#   MAE: 272.52
#   RMSE: 412.24
#   MAPE: 33.37%
#   RMSPE: 61.02%
#   R^2: 0.54
#
# Overall Metrics for Dataset 6:
#   MSE: 98686.32
#   MAE: 205.72
#   RMSE: 314.14
#   MAPE: 23.04%
#   RMSPE: 33.78%
#   R^2: 0.78
#   Percentage within 10%: 34.23%
#   Percentage within 50%: 90.07%
#   Percentage within 100%: 98.30%
# Dataset 7, Value 6.0:
#   MSE: 130123.18
#   MAE: 255.71
#   RMSE: 360.73
#   MAPE: 24.62%
#   RMSPE: 35.86%
#   R^2: 0.73
# Dataset 7, Value 3.0:
#   MSE: 27622.48
#   MAE: 101.53
#   RMSE: 166.20
#   MAPE: 19.65%
#   RMSPE: 27.39%
#   R^2: 0.73
# Dataset 7, Value 5.0:
#   MSE: 133277.79
#   MAE: 238.67
#   RMSE: 365.07
#   MAPE: 27.25%
#   RMSPE: 46.20%
#   R^2: 0.69
# Dataset 7, Value 4.0:
#   MSE: 123484.73
#   MAE: 231.96
#   RMSE: 351.40
#   MAPE: 23.52%
#   RMSPE: 34.52%
#   R^2: 0.66
# Dataset 7, Value 7.0:
#   MSE: 217438.65
#   MAE: 310.34
#   RMSE: 466.30
#   MAPE: 35.97%
#   RMSPE: 63.28%
#   R^2: 0.44
# Dataset 7, Value 1.0:
#   MSE: 453734.85
#   MAE: 513.39
#   RMSE: 673.60
#   MAPE: 40.27%
#   RMSPE: 46.28%
#   R^2: -0.38
# Dataset 7, Value 2.0:
#   MSE: 542559.24
#   MAE: 557.55
#   RMSE: 736.59
#   MAPE: 73.22%
#   RMSPE: 107.64%
#   R^2: -2.80
#
# Overall Metrics for Dataset 7:
#   MSE: 100837.16
#   MAE: 208.51
#   RMSE: 317.55
#   MAPE: 23.24%
#   RMSPE: 34.16%
#   R^2: 0.77
#   Percentage within 10%: 33.77%
#   Percentage within 50%: 90.10%
#   Percentage within 100%: 98.11%
# Dataset 8, Value 6.0:
#   MSE: 147836.48
#   MAE: 278.20
#   RMSE: 384.50
#   MAPE: 25.60%
#   RMSPE: 37.68%
#   R^2: 0.68
# Dataset 8, Value 1.0:
#   MSE: 54944.46
#   MAE: 146.17
#   RMSE: 234.40
#   MAPE: 20.94%
#   RMSPE: 30.53%
#   R^2: 0.71
# Dataset 8, Value 7.0:
#   MSE: 19065.70
#   MAE: 85.07
#   RMSE: 138.08
#   MAPE: 18.56%
#   RMSPE: 26.26%
#   R^2: 0.66
# Dataset 8, Value 4.0:
#   MSE: 146409.93
#   MAE: 271.82
#   RMSE: 382.64
#   MAPE: 23.79%
#   RMSPE: 35.97%
#   R^2: 0.74
# Dataset 8, Value 8.0:
#   MSE: 141182.74
#   MAE: 249.28
#   RMSE: 375.74
#   MAPE: 28.43%
#   RMSPE: 46.33%
#   R^2: 0.63
# Dataset 8, Value 5.0:
#   MSE: 110674.67
#   MAE: 219.77
#   RMSE: 332.68
#   MAPE: 23.46%
#   RMSPE: 33.98%
#   R^2: 0.65
# Dataset 8, Value 2.0:
#   MSE: 173404.41
#   MAE: 273.95
#   RMSE: 416.42
#   MAPE: 32.97%
#   RMSPE: 58.89%
#   R^2: 0.53
# Skipping value 3.0 for dataset 8 due to empty subset.
#
# Overall Metrics for Dataset 8:
#   MSE: 97735.70
#   MAE: 203.03
#   RMSE: 312.63
#   MAPE: 22.74%
#   RMSPE: 33.90%
#   R^2: 0.78
#   Percentage within 10%: 35.03%
#   Percentage within 50%: 90.24%
#   Percentage within 100%: 98.22%
# Dataset 9, Value 4.0:
#   MSE: 141771.27
#   MAE: 275.01
#   RMSE: 376.53
#   MAPE: 26.02%
#   RMSPE: 38.70%
#   R^2: 0.69
# Dataset 9, Value 5.0:
#   MSE: 68975.75
#   MAE: 170.44
#   RMSE: 262.63
#   MAPE: 21.55%
#   RMSPE: 30.12%
#   R^2: 0.66
# Dataset 9, Value 7.0:
#   MSE: 23349.15
#   MAE: 92.13
#   RMSE: 152.80
#   MAPE: 19.35%
#   RMSPE: 26.91%
#   R^2: 0.67
# Dataset 9, Value 1.0:
#   MSE: 145112.52
#   MAE: 266.06
#   RMSE: 380.94
#   MAPE: 23.32%
#   RMSPE: 34.53%
#   R^2: 0.74
# Dataset 9, Value 3.0:
#   MSE: 103021.07
#   MAE: 214.78
#   RMSE: 320.97
#   MAPE: 25.65%
#   RMSPE: 42.28%
#   R^2: 0.72
# Dataset 9, Value 6.0:
#   MSE: 202358.38
#   MAE: 296.11
#   RMSE: 449.84
#   MAPE: 33.95%
#   RMSPE: 59.22%
#   R^2: 0.48
# Dataset 9, Value 8.0:
#   MSE: 489123.46
#   MAE: 481.21
#   RMSE: 699.37
#   MAPE: 29.17%
#   RMSPE: 35.18%
#   R^2: -0.00
# Dataset 9, Value 2.0:
#   MSE: 487650.00
#   MAE: 549.60
#   RMSE: 698.32
#   MAPE: 71.65%
#   RMSPE: 100.59%
#   R^2: -2.41
# Skipping value 9.0 for dataset 9 due to empty subset.
#
# Overall Metrics for Dataset 9:
#   MSE: 97919.03
#   MAE: 205.08
#   RMSE: 312.92
#   MAPE: 22.92%
#   RMSPE: 33.75%
#   R^2: 0.78
#   Percentage within 10%: 34.30%
#   Percentage within 50%: 90.25%
#   Percentage within 100%: 98.17%
# Dataset 10, Value 2.0:
#   MSE: 144127.25
#   MAE: 275.10
#   RMSE: 379.64
#   MAPE: 25.61%
#   RMSPE: 39.42%
#   R^2: 0.69
# Dataset 10, Value 3.0:
#   MSE: 57240.27
#   MAE: 148.67
#   RMSE: 239.25
#   MAPE: 21.16%
#   RMSPE: 30.09%
#   R^2: 0.69
# Dataset 10, Value 6.0:
#   MSE: 21040.72
#   MAE: 88.87
#   RMSE: 145.05
#   MAPE: 19.31%
#   RMSPE: 27.47%
#   R^2: 0.63
# Dataset 10, Value 9.0:
#   MSE: 148265.77
#   MAE: 270.75
#   RMSE: 385.05
#   MAPE: 23.97%
#   RMSPE: 36.75%
#   R^2: 0.74
# Dataset 10, Value 7.0:
#   MSE: 133395.92
#   MAE: 241.76
#   RMSE: 365.23
#   MAPE: 27.70%
#   RMSPE: 44.98%
#   R^2: 0.65
# Dataset 10, Value 8.0:
#   MSE: 115066.00
#   MAE: 216.76
#   RMSE: 339.21
#   MAPE: 23.21%
#   RMSPE: 33.72%
#   R^2: 0.63
# Dataset 10, Value 1.0:
#   MSE: 77773.62
#   MAE: 184.52
#   RMSE: 278.88
#   MAPE: 34.57%
#   RMSPE: 54.76%
#   R^2: 0.03
# Dataset 10, Value 10.0:
#   MSE: 201872.43
#   MAE: 293.83
#   RMSE: 449.30
#   MAPE: 27.72%
#   RMSPE: 48.01%
#   R^2: 0.49
# Dataset 10, Value 5.0:
#   MSE: 389504.17
#   MAE: 461.42
#   RMSE: 624.10
#   MAPE: 63.71%
#   RMSPE: 92.83%
#   R^2: -1.73
# Skipping value 4.0 for dataset 10 due to empty subset.
#
# Overall Metrics for Dataset 10:
#   MSE: 98546.54
#   MAE: 203.06
#   RMSE: 313.92
#   MAPE: 22.93%
#   RMSPE: 34.54%
#   R^2: 0.78
#   Percentage within 10%: 35.51%
#   Percentage within 50%: 90.12%
#   Percentage within 100%: 98.06%
# Dataset 11, Value 5.0:
#   MSE: 134074.04
#   MAE: 262.24
#   RMSE: 366.16
#   MAPE: 24.30%
#   RMSPE: 35.07%
#   R^2: 0.73
# Dataset 11, Value 9.0:
#   MSE: 39618.13
#   MAE: 120.40
#   RMSE: 199.04
#   MAPE: 21.37%
#   RMSPE: 30.37%
#   R^2: 0.67
# Dataset 11, Value 2.0:
#   MSE: 35354.29
#   MAE: 104.84
#   RMSE: 188.03
#   MAPE: 19.06%
#   RMSPE: 28.43%
#   R^2: 0.74
# Dataset 11, Value 1.0:
#   MSE: 141414.38
#   MAE: 251.50
#   RMSE: 376.05
#   MAPE: 27.67%
#   RMSPE: 42.62%
#   R^2: 0.67
# Dataset 11, Value 3.0:
#   MSE: 125897.11
#   MAE: 234.65
#   RMSE: 354.82
#   MAPE: 23.70%
#   RMSPE: 35.04%
#   R^2: 0.65
# Dataset 11, Value 11.0:
#   MSE: 210694.09
#   MAE: 331.11
#   RMSE: 459.01
#   MAPE: 30.63%
#   RMSPE: 44.26%
#   R^2: 0.50
# Dataset 11, Value 4.0:
#   MSE: 119778.17
#   MAE: 220.73
#   RMSE: 346.09
#   MAPE: 38.99%
#   RMSPE: 69.57%
#   R^2: -0.41
# Dataset 11, Value 10.0:
#   MSE: 220264.85
#   MAE: 306.46
#   RMSE: 469.32
#   MAPE: 27.22%
#   RMSPE: 41.88%
#   R^2: 0.50
# Dataset 11, Value 6.0:
#   MSE: 126169.31
#   MAE: 251.87
#   RMSE: 355.20
#   MAPE: 25.90%
#   RMSPE: 36.46%
#   R^2: 0.33
# Dataset 11, Value 8.0:
#   MSE: 542559.24
#   MAE: 557.55
#   RMSE: 736.59
#   MAPE: 73.22%
#   RMSPE: 107.64%
#   R^2: -2.80
# Skipping value 7.0 for dataset 11 due to empty subset.
#
# Overall Metrics for Dataset 11:
#   MSE: 100639.91
#   MAE: 207.89
#   RMSE: 317.24
#   MAPE: 23.14%
#   RMSPE: 33.84%
#   R^2: 0.77
#   Percentage within 10%: 34.13%
#   Percentage within 50%: 89.58%
#   Percentage within 100%: 98.19%
# Dataset 12, Value 4.0:
#   MSE: 78570.28
#   MAE: 179.09
#   RMSE: 280.30
#   MAPE: 20.81%
#   RMSPE: 29.40%
#   R^2: 0.69
# Dataset 12, Value 2.0:
#   MSE: 140630.43
#   MAE: 276.02
#   RMSE: 375.01
#   MAPE: 25.60%
#   RMSPE: 38.51%
#   R^2: 0.70
# Dataset 12, Value 6.0:
#   MSE: 24719.14
#   MAE: 90.98
#   RMSE: 157.22
#   MAPE: 17.76%
#   RMSPE: 25.59%
#   R^2: 0.74
# Dataset 12, Value 8.0:
#   MSE: 34806.78
#   MAE: 110.82
#   RMSE: 186.57
#   MAPE: 22.35%
#   RMSPE: 32.49%
#   R^2: 0.60
# Dataset 12, Value 12.0:
#   MSE: 153813.26
#   MAE: 276.03
#   RMSE: 392.19
#   MAPE: 23.95%
#   RMSPE: 36.05%
#   R^2: 0.73
# Dataset 12, Value 10.0:
#   MSE: 163353.51
#   MAE: 244.92
#   RMSE: 404.17
#   MAPE: 26.01%
#   RMSPE: 39.04%
#   R^2: 0.59
# Dataset 12, Value 11.0:
#   MSE: 124293.90
#   MAE: 229.02
#   RMSE: 352.55
#   MAPE: 24.17%
#   RMSPE: 36.28%
#   R^2: 0.62
# Dataset 12, Value 1.0:
#   MSE: 120860.00
#   MAE: 242.24
#   RMSE: 347.65
#   MAPE: 28.19%
#   RMSPE: 47.95%
#   R^2: 0.69
# Dataset 12, Value 7.0:
#   MSE: 166642.54
#   MAE: 273.89
#   RMSE: 408.22
#   MAPE: 33.10%
#   RMSPE: 51.96%
#   R^2: 0.61
# Dataset 12, Value 3.0:
#   MSE: 489123.46
#   MAE: 481.21
#   RMSE: 699.37
#   MAPE: 29.17%
#   RMSPE: 35.18%
#   R^2: -0.00
# Dataset 12, Value 5.0:
#   MSE: 112743.63
#   MAE: 247.41
#   RMSE: 335.77
#   MAPE: 21.00%
#   RMSPE: 27.13%
#   R^2: 0.50
# Dataset 12, Value 9.0:
#   MSE: 542559.24
#   MAE: 557.55
#   RMSE: 736.59
#   MAPE: 73.22%
#   RMSPE: 107.64%
#   R^2: -2.80
#
# Overall Metrics for Dataset 12:
#   MSE: 99999.23
#   MAE: 204.85
#   RMSE: 316.23
#   MAPE: 22.95%
#   RMSPE: 34.28%
#   R^2: 0.77
#   Percentage within 10%: 35.50%
#   Percentage within 50%: 89.99%
#   Percentage within 100%: 98.14%
# Dataset 13, Value 5.0:
#   MSE: 118281.47
#   MAE: 240.25
#   RMSE: 343.92
#   MAPE: 24.43%
#   RMSPE: 36.01%
#   R^2: 0.72
# Dataset 13, Value 3.0:
#   MSE: 144780.46
#   MAE: 265.70
#   RMSE: 380.50
#   MAPE: 23.73%
#   RMSPE: 36.12%
#   R^2: 0.74
# Dataset 13, Value 11.0:
#   MSE: 23923.80
#   MAE: 95.87
#   RMSE: 154.67
#   MAPE: 19.26%
#   RMSPE: 26.76%
#   R^2: 0.70
# Dataset 13, Value 2.0:
#   MSE: 134522.79
#   MAE: 242.84
#   RMSE: 366.77
#   MAPE: 25.03%
#   RMSPE: 36.45%
#   R^2: 0.68
# Dataset 13, Value 1.0:
#   MSE: 116280.95
#   MAE: 220.63
#   RMSE: 341.00
#   MAPE: 23.93%
#   RMSPE: 35.19%
#   R^2: 0.63
# Dataset 13, Value 4.0:
#   MSE: 134049.99
#   MAE: 253.43
#   RMSE: 366.13
#   MAPE: 28.51%
#   RMSPE: 44.97%
#   R^2: 0.68
# Dataset 13, Value 8.0:
#   MSE: 217344.56
#   MAE: 331.86
#   RMSE: 466.20
#   MAPE: 34.34%
#   RMSPE: 54.21%
#   R^2: 0.47
# Dataset 13, Value 7.0:
#   MSE: 81225.55
#   MAE: 188.73
#   RMSE: 285.00
#   MAPE: 29.13%
#   RMSPE: 37.12%
#   R^2: 0.12
# Dataset 13, Value 9.0:
#   MSE: 136105.74
#   MAE: 280.80
#   RMSE: 368.93
#   MAPE: 26.00%
#   RMSPE: 35.17%
#   R^2: 0.42
# Dataset 13, Value 10.0:
#   MSE: 232877.48
#   MAE: 308.64
#   RMSE: 482.57
#   MAPE: 30.98%
#   RMSPE: 56.24%
#   R^2: 0.50
# Dataset 13, Value 12.0:
#   MSE: 342757.53
#   MAE: 466.90
#   RMSE: 585.45
#   MAPE: 60.70%
#   RMSPE: 82.87%
#   R^2: -1.40
# Skipping value 6.0 for dataset 13 due to empty subset.
# Skipping value 13.0 for dataset 13 due to empty subset.
#
# Overall Metrics for Dataset 13:
#   MSE: 99867.85
#   MAE: 205.91
#   RMSE: 316.02
#   MAPE: 23.01%
#   RMSPE: 34.16%
#   R^2: 0.77
#   Percentage within 10%: 34.89%
#   Percentage within 50%: 89.90%
#   Percentage within 100%: 98.20%
# Dataset 14, Value 8.0:
#   MSE: 128721.41
#   MAE: 254.27
#   RMSE: 358.78
#   MAPE: 24.47%
#   RMSPE: 36.03%
#   R^2: 0.70
# Dataset 14, Value 4.0:
#   MSE: 37063.27
#   MAE: 120.29
#   RMSE: 192.52
#   MAPE: 21.91%
#   RMSPE: 31.19%
#   R^2: 0.68
# Dataset 14, Value 13.0:
#   MSE: 25825.18
#   MAE: 93.72
#   RMSE: 160.70
#   MAPE: 18.30%
#   RMSPE: 26.14%
#   R^2: 0.73
# Dataset 14, Value 3.0:
#   MSE: 147473.98
#   MAE: 270.28
#   RMSE: 384.02
#   MAPE: 23.56%
#   RMSPE: 35.65%
#   R^2: 0.73
# Dataset 14, Value 1.0:
#   MSE: 117780.56
#   MAE: 231.08
#   RMSE: 343.19
#   MAPE: 27.24%
#   RMSPE: 44.58%
#   R^2: 0.68
# Dataset 14, Value 2.0:
#   MSE: 116361.10
#   MAE: 223.97
#   RMSE: 341.12
#   MAPE: 23.94%
#   RMSPE: 35.03%
#   R^2: 0.63
# Dataset 14, Value 14.0:
#   MSE: 195078.85
#   MAE: 331.52
#   RMSE: 441.68
#   MAPE: 30.79%
#   RMSPE: 43.02%
#   R^2: 0.54
# Dataset 14, Value 6.0:
#   MSE: 85795.46
#   MAE: 205.96
#   RMSE: 292.91
#   MAPE: 39.28%
#   RMSPE: 61.04%
#   R^2: 0.06
# Dataset 14, Value 10.0:
#   MSE: 489123.46
#   MAE: 481.21
#   RMSE: 699.37
#   MAPE: 29.17%
#   RMSPE: 35.18%
#   R^2: -0.00
# Dataset 14, Value 5.0:
#   MSE: 207453.42
#   MAE: 300.18
#   RMSE: 455.47
#   MAPE: 26.80%
#   RMSPE: 42.91%
#   R^2: 0.47
# Dataset 14, Value 11.0:
#   MSE: 342757.53
#   MAE: 466.90
#   RMSE: 585.45
#   MAPE: 60.70%
#   RMSPE: 82.87%
#   R^2: -1.40
# Skipping value 9.0 for dataset 14 due to empty subset.
# Skipping value 12.0 for dataset 14 due to empty subset.
# Skipping value 7.0 for dataset 14 due to empty subset.
#
# Overall Metrics for Dataset 14:
#   MSE: 99124.27
#   MAE: 205.52
#   RMSE: 314.84
#   MAPE: 23.15%
#   RMSPE: 34.26%
#   R^2: 0.78
#   Percentage within 10%: 34.75%
#   Percentage within 50%: 89.97%
#   Percentage within 100%: 98.09%
# Dataset 15, Value 6.0:
#   MSE: 133770.30
#   MAE: 259.91
#   RMSE: 365.75
#   MAPE: 24.71%
#   RMSPE: 35.00%
#   R^2: 0.70
# Dataset 15, Value 15.0:
#   MSE: 56146.34
#   MAE: 146.86
#   RMSE: 236.95
#   MAPE: 23.71%
#   RMSPE: 33.60%
#   R^2: 0.78
# Dataset 15, Value 9.0:
#   MSE: 454954.37
#   MAE: 474.20
#   RMSE: 674.50
#   MAPE: 30.16%
#   RMSPE: 35.77%
#   R^2: 0.02
# Dataset 15, Value 12.0:
#   MSE: 523530.67
#   MAE: 508.43
#   RMSE: 723.55
#   MAPE: 50.68%
#   RMSPE: 74.44%
#   R^2: -0.33
# Dataset 15, Value 7.0:
#   MSE: 297282.64
#   MAE: 401.17
#   RMSE: 545.24
#   MAPE: 37.92%
#   RMSPE: 50.82%
#   R^2: 0.01
# Dataset 15, Value 4.0:
#   MSE: 475734.21
#   MAE: 508.62
#   RMSE: 689.73
#   MAPE: 38.40%
#   RMSPE: 45.72%
#   R^2: -0.14
# Skipping value 14.0 for dataset 15 due to empty subset.
# Dataset 15, Value 2.0:
#   MSE: 126937.84
#   MAE: 261.25
#   RMSE: 356.28
#   MAPE: 35.96%
#   RMSPE: 56.03%
#   R^2: 0.44
# Dataset 15, Value 3.0:
#   MSE: 1280494.19
#   MAE: 955.36
#   RMSE: 1131.59
#   MAPE: 147.76%
#   RMSPE: 199.03%
#   R^2: -19.30
# Dataset 15, Value 8.0:
#   MSE: 83674.41
#   MAE: 172.88
#   RMSE: 289.27
#   MAPE: 29.27%
#   RMSPE: 35.65%
#   R^2: -0.48
#
# Overall Metrics for Dataset 15:
#   MSE: 115272.42
#   MAE: 224.89
#   RMSE: 339.52
#   MAPE: 25.00%
#   RMSPE: 36.08%
#   R^2: 0.74
#   Percentage within 10%: 29.96%
#   Percentage within 50%: 88.47%
#   Percentage within 100%: 98.00%

# %%
# Load the datasets
data_path = '../13. Data from R 50000/'
X_train = pd.read_parquet(data_path + 'X_train_2024.parquet', engine='pyarrow')
X_test = pd.read_parquet(data_path + 'X_test_2024.parquet', engine='pyarrow')
seed_num = 2024

# Load y_train and y_test
y_train = pd.read_parquet(data_path + 'y_train_2024.parquet').iloc[:, 0]
y_test = pd.read_parquet(data_path + 'y_test_2024.parquet').iloc[:, 0]

# List of categorical variables
categorical_vars = [
    "MARITALSTATUS", "NOOFCHILDREN", "HOMEOWNERIND", "VEHICLE_LEFTORRIGHTHANDDRIVE",
    "DRIVER1_LICENCETYPE", "DRIVER2_LICENCETYPE", "DRIVER3_LICENCETYPE", "DRIVER4_LICENCETYPE",
    "DRIVER1_OTHERVEHICLEOWNEDIND", "DRIVER2_OTHERVEHICLEOWNEDIND", "DRIVER3_OTHERVEHICLEOWNEDIND",
    "DRIVER4_OTHERVEHICLEOWNEDIND", "MONTHLYPAYMENTSIND", "VEHICLE_USE_TYPE", "VEHICLEOVERNIGHTLOCATION",
    "VEHICLE_OWNERSHIP", "VEHICLE_MODIFIEDIND", "VEHICLE_BODYTYPE", "VEHICLE_FUELTYPE",
    "VEHICLE_TRANSMISSIONTYPE", "INDICATOR_NRCONVICTIONS_RECENT", "INDICATOR_CLAIMSCOUNT_RECENT"
]

# Define numerical columns by excluding categorical ones
numerical_vars = [col for col in X_train.columns if col not in categorical_vars]

# Dictionaries to store models, predictions, errors, and subset sizes
model_store = {}
prediction_store = {}
errors_store = {}
subset_sizes = {}

# Initialize lists to store the combined true values and predictions across all datasets
all_y_test_global = []
all_y_pred_global = []

# Function to calculate percentage within tolerance
def calculate_within_tolerance(y_true, y_pred, tolerance):
    within_tolerance = abs(y_true - y_pred) / y_true <= tolerance
    percentage_within_tolerance = within_tolerance.mean() * 100
    return percentage_within_tolerance

# Processing datasets
for i in range(2, 16):  # Loop from 2 to 15 clusters
    X_train_additional = pd.read_parquet(f'{data_path}X_train_kamila_c{i}_seed_2024.parquet')
    X_test_additional = pd.read_parquet(f'{data_path}X_test_kamila_c{i}_seed_2024.parquet')
    
    # Append the last columns to the main datasets
    X_train[f'additional_feature_{i}'] = X_train_additional.iloc[:, -1]
    X_test[f'additional_feature_{i}'] = X_test_additional.iloc[:, -1]

    # Initialize error storage for this dataset
    errors_store[i] = {}
    subset_sizes[i] = {}
    
    # Unique values in the 'additional_feature' column
    unique_values = np.sort(X_train[f'additional_feature_{i}'].unique())

    # Initialize lists to store the combined true values and predictions for this dataset
    dataset_y_test = []
    dataset_y_pred = []
    
    for value in unique_values:
        # Split the data by 'additional_feature'
        X_train_subset = X_train[X_train[f'additional_feature_{i}'] == value]
        X_test_subset = X_test[X_test[f'additional_feature_{i}'] == value]
        y_train_subset = y_train[X_train[f'additional_feature_{i}'] == value]
        y_test_subset = y_test[X_test[f'additional_feature_{i}'] == value]
        
        # Skip if the subset is empty
        if X_train_subset.empty or X_test_subset.empty or y_train_subset.empty or y_test_subset.empty:
            print(f"Skipping value {value} for dataset {i} due to empty subset.")
            continue

        # Initialize and train the XGBoost model
        model = XGBRegressor(random_state=2024)
        model.fit(X_train_subset.drop(columns=[f'additional_feature_{i}']), y_train_subset)
        model_store[(i, value)] = model

        # Predict on the corresponding test set
        y_pred_subset = model.predict(X_test_subset.drop(columns=[f'additional_feature_{i}']))
        prediction_store[(i, value)] = y_pred_subset

        # Combine predictions and true values for this dataset
        dataset_y_test.extend(y_test_subset.tolist())
        dataset_y_pred.extend(y_pred_subset.tolist())

        # Calculate and store relative prediction errors
        relative_errors = (y_pred_subset - y_test_subset) / y_test_subset
        errors_store[i][value] = relative_errors
        subset_sizes[i][value] = len(y_test_subset)

        # Print metrics for each subset
        mse = mean_squared_error(y_test_subset, y_pred_subset)
        mae = mean_absolute_error(y_test_subset, y_pred_subset)
        rmse = np.sqrt(mse)
        mape = np.mean(np.abs((y_test_subset - y_pred_subset) / y_test_subset)) * 100
        rmspe = np.sqrt(np.mean(np.square((y_test_subset - y_pred_subset) / y_test_subset))) * 100
        r2 = r2_score(y_test_subset, y_pred_subset)
        print(f"Dataset {i}, Value {value}:")
        print(f"  MSE: {mse:.2f}")
        print(f"  MAE: {mae:.2f}")
        print(f"  RMSE: {rmse:.2f}")
        print(f"  MAPE: {mape:.2f}%")
        print(f"  RMSPE: {rmspe:.2f}%")
        print(f"  R^2: {r2:.2f}")

    # Convert combined lists to numpy arrays for overall evaluation for this dataset
    dataset_y_test = np.array(dataset_y_test)
    dataset_y_pred = np.array(dataset_y_pred)

    # Combine the current dataset predictions with the global lists
    all_y_test_global.extend(dataset_y_test)
    all_y_pred_global.extend(dataset_y_pred)

    # Calculate overall metrics for the current dataset
    overall_mse = mean_squared_error(dataset_y_test, dataset_y_pred)
    overall_mae = mean_absolute_error(dataset_y_test, dataset_y_pred)
    overall_rmse = np.sqrt(overall_mse)
    overall_mape = np.mean(np.abs((dataset_y_test - dataset_y_pred) / dataset_y_test)) * 100
    overall_rmspe = np.sqrt(np.mean(np.square((dataset_y_test - dataset_y_pred) / dataset_y_test))) * 100
    overall_r2 = r2_score(dataset_y_test, dataset_y_pred)

    # Calculate percentage within tolerance for the current dataset
    overall_within_10 = calculate_within_tolerance(dataset_y_test, dataset_y_pred, 0.10)
    overall_within_50 = calculate_within_tolerance(dataset_y_test, dataset_y_pred, 0.50)
    overall_within_100 = calculate_within_tolerance(dataset_y_test, dataset_y_pred, 1.00)

    # Add overall dataset differences for plotting
    errors_store[i]['overall'] = (dataset_y_pred - dataset_y_test) / dataset_y_test

    # Display overall metrics for the current dataset
    print(f"\nOverall Metrics for Dataset {i}:")
    print(f"  MSE: {overall_mse:.2f}")
    print(f"  MAE: {overall_mae:.2f}")
    print(f"  RMSE: {overall_rmse:.2f}")
    print(f"  MAPE: {overall_mape:.2f}%")
    print(f"  RMSPE: {overall_rmspe:.2f}%")
    print(f"  R^2: {overall_r2:.2f}")
    print(f"  Percentage within 10%: {overall_within_10:.2f}%")
    print(f"  Percentage within 50%: {overall_within_50:.2f}%")
    print(f"  Percentage within 100%: {overall_within_100:.2f}%")

# Plotting density curves of relative prediction errors for each dataset
for i in errors_store:
    plt.figure(figsize=(12, 8))
    sorted_clusters = sorted(errors_store[i].keys(), key=lambda x: int(x) if x != 'overall' else float('inf'))  # Sort by cluster number
    for value in sorted_clusters:
        if value == 'overall':
            sns.kdeplot(errors_store[i][value], label=f'Overall Dataset {i}', linewidth=2.5)
        else:
            sns.kdeplot(errors_store[i][value], label=f'Cluster {value} (n={subset_sizes[i][value]})')
    plt.title(f'Density Plot of Relative Prediction Errors for Dataset {i}')
    plt.xlabel('Relative Prediction Error (Error / True Value)')
    plt.ylabel('Density')
    plt.legend()
    plt.show()
# Out:
# Dataset 2, Value 1.0:
#   MSE: 132107.57
#   MAE: 259.79
#   RMSE: 363.47
#   MAPE: 24.71%
#   RMSPE: 35.13%
#   R^2: 0.72
# Dataset 2, Value 2.0:
#   MSE: 34738.44
#   MAE: 112.19
#   RMSE: 186.38
#   MAPE: 20.54%
#   RMSPE: 28.70%
#   R^2: 0.71
#
# Overall Metrics for Dataset 2:
#   MSE: 98807.33
#   MAE: 209.31
#   RMSE: 314.34
#   MAPE: 23.28%
#   RMSPE: 33.07%
#   R^2: 0.78
#   Percentage within 10%: 31.59%
#   Percentage within 50%: 90.14%
#   Percentage within 100%: 98.36%
# Dataset 3, Value 1.0:
#   MSE: 120554.58
#   MAE: 244.65
#   RMSE: 347.21
#   MAPE: 24.63%
#   RMSPE: 36.30%
#   R^2: 0.70
# Dataset 3, Value 2.0:
#   MSE: 28621.48
#   MAE: 103.51
#   RMSE: 169.18
#   MAPE: 19.67%
#   RMSPE: 27.05%
#   R^2: 0.70
# Dataset 3, Value 3.0:
#   MSE: 138939.56
#   MAE: 262.46
#   RMSE: 372.75
#   MAPE: 24.19%
#   RMSPE: 35.65%
#   R^2: 0.75
#
# Overall Metrics for Dataset 3:
#   MSE: 96576.17
#   MAE: 205.21
#   RMSE: 310.77
#   MAPE: 22.97%
#   RMSPE: 33.52%
#   R^2: 0.78
#   Percentage within 10%: 33.28%
#   Percentage within 50%: 90.50%
#   Percentage within 100%: 98.18%
# Dataset 4, Value 1.0:
#   MSE: 118986.48
#   MAE: 224.74
#   RMSE: 344.94
#   MAPE: 24.20%
#   RMSPE: 35.14%
#   R^2: 0.64
# Dataset 4, Value 2.0:
#   MSE: 110131.17
#   MAE: 221.86
#   RMSE: 331.86
#   MAPE: 22.96%
#   RMSPE: 32.99%
#   R^2: 0.75
# Dataset 4, Value 3.0:
#   MSE: 24862.09
#   MAE: 94.84
#   RMSE: 157.68
#   MAPE: 19.48%
#   RMSPE: 27.48%
#   R^2: 0.68
# Dataset 4, Value 4.0:
#   MSE: 136938.08
#   MAE: 268.87
#   RMSE: 370.05
#   MAPE: 25.44%
#   RMSPE: 38.01%
#   R^2: 0.72
#
# Overall Metrics for Dataset 4:
#   MSE: 99077.42
#   MAE: 206.52
#   RMSE: 314.77
#   MAPE: 23.04%
#   RMSPE: 33.72%
#   R^2: 0.78
#   Percentage within 10%: 34.01%
#   Percentage within 50%: 90.11%
#   Percentage within 100%: 98.25%
# Dataset 5, Value 1.0:
#   MSE: 118289.33
#   MAE: 239.39
#   RMSE: 343.93
#   MAPE: 24.50%
#   RMSPE: 36.94%
#   R^2: 0.72
# Dataset 5, Value 2.0:
#   MSE: 168179.38
#   MAE: 268.19
#   RMSE: 410.10
#   MAPE: 29.17%
#   RMSPE: 46.00%
#   R^2: 0.56
# Dataset 5, Value 3.0:
#   MSE: 113776.63
#   MAE: 222.19
#   RMSE: 337.31
#   MAPE: 24.14%
#   RMSPE: 35.31%
#   R^2: 0.64
# Dataset 5, Value 4.0:
#   MSE: 25418.15
#   MAE: 98.77
#   RMSE: 159.43
#   MAPE: 19.78%
#   RMSPE: 27.68%
#   R^2: 0.69
# Dataset 5, Value 5.0:
#   MSE: 146971.91
#   MAE: 270.14
#   RMSE: 383.37
#   MAPE: 24.13%
#   RMSPE: 35.67%
#   R^2: 0.74
#
# Overall Metrics for Dataset 5:
#   MSE: 99512.34
#   MAE: 206.17
#   RMSE: 315.46
#   MAPE: 23.16%
#   RMSPE: 34.37%
#   R^2: 0.77
#   Percentage within 10%: 34.44%
#   Percentage within 50%: 89.72%
#   Percentage within 100%: 98.23%
# Dataset 6, Value 1.0:
#   MSE: 22491.76
#   MAE: 93.83
#   RMSE: 149.97
#   MAPE: 19.14%
#   RMSPE: 26.48%
#   R^2: 0.69
# Dataset 6, Value 2.0:
#   MSE: 143578.90
#   MAE: 254.52
#   RMSE: 378.92
#   MAPE: 28.33%
#   RMSPE: 46.84%
#   R^2: 0.64
# Dataset 6, Value 3.0:
#   MSE: 133074.90
#   MAE: 260.95
#   RMSE: 364.79
#   MAPE: 24.93%
#   RMSPE: 36.99%
#   R^2: 0.70
# Dataset 6, Value 4.0:
#   MSE: 115917.58
#   MAE: 231.90
#   RMSE: 340.47
#   MAPE: 23.41%
#   RMSPE: 33.24%
#   R^2: 0.77
# Dataset 6, Value 5.0:
#   MSE: 114131.28
#   MAE: 218.44
#   RMSE: 337.83
#   MAPE: 23.94%
#   RMSPE: 35.23%
#   R^2: 0.63
# Dataset 6, Value 6.0:
#   MSE: 169941.30
#   MAE: 272.52
#   RMSE: 412.24
#   MAPE: 33.37%
#   RMSPE: 61.02%
#   R^2: 0.54
#
# Overall Metrics for Dataset 6:
#   MSE: 98686.32
#   MAE: 205.72
#   RMSE: 314.14
#   MAPE: 23.04%
#   RMSPE: 33.78%
#   R^2: 0.78
#   Percentage within 10%: 34.23%
#   Percentage within 50%: 90.07%
#   Percentage within 100%: 98.30%
# Dataset 7, Value 1.0:
#   MSE: 453734.85
#   MAE: 513.39
#   RMSE: 673.60
#   MAPE: 40.27%
#   RMSPE: 46.28%
#   R^2: -0.38
# Dataset 7, Value 2.0:
#   MSE: 542559.24
#   MAE: 557.55
#   RMSE: 736.59
#   MAPE: 73.22%
#   RMSPE: 107.64%
#   R^2: -2.80
# Dataset 7, Value 3.0:
#   MSE: 27622.48
#   MAE: 101.53
#   RMSE: 166.20
#   MAPE: 19.65%
#   RMSPE: 27.39%
#   R^2: 0.73
# Dataset 7, Value 4.0:
#   MSE: 123484.73
#   MAE: 231.96
#   RMSE: 351.40
#   MAPE: 23.52%
#   RMSPE: 34.52%
#   R^2: 0.66
# Dataset 7, Value 5.0:
#   MSE: 133277.79
#   MAE: 238.67
#   RMSE: 365.07
#   MAPE: 27.25%
#   RMSPE: 46.20%
#   R^2: 0.69
# Dataset 7, Value 6.0:
#   MSE: 130123.18
#   MAE: 255.71
#   RMSE: 360.73
#   MAPE: 24.62%
#   RMSPE: 35.86%
#   R^2: 0.73
# Dataset 7, Value 7.0:
#   MSE: 217438.65
#   MAE: 310.34
#   RMSE: 466.30
#   MAPE: 35.97%
#   RMSPE: 63.28%
#   R^2: 0.44
#
# Overall Metrics for Dataset 7:
#   MSE: 100837.16
#   MAE: 208.51
#   RMSE: 317.55
#   MAPE: 23.24%
#   RMSPE: 34.16%
#   R^2: 0.77
#   Percentage within 10%: 33.77%
#   Percentage within 50%: 90.10%
#   Percentage within 100%: 98.11%
# Dataset 8, Value 1.0:
#   MSE: 54944.46
#   MAE: 146.17
#   RMSE: 234.40
#   MAPE: 20.94%
#   RMSPE: 30.53%
#   R^2: 0.71
# Dataset 8, Value 2.0:
#   MSE: 173404.41
#   MAE: 273.95
#   RMSE: 416.42
#   MAPE: 32.97%
#   RMSPE: 58.89%
#   R^2: 0.53
# Skipping value 3.0 for dataset 8 due to empty subset.
# Dataset 8, Value 4.0:
#   MSE: 146409.93
#   MAE: 271.82
#   RMSE: 382.64
#   MAPE: 23.79%
#   RMSPE: 35.97%
#   R^2: 0.74
# Dataset 8, Value 5.0:
#   MSE: 110674.67
#   MAE: 219.77
#   RMSE: 332.68
#   MAPE: 23.46%
#   RMSPE: 33.98%
#   R^2: 0.65
# Dataset 8, Value 6.0:
#   MSE: 147836.48
#   MAE: 278.20
#   RMSE: 384.50
#   MAPE: 25.60%
#   RMSPE: 37.68%
#   R^2: 0.68
# Dataset 8, Value 7.0:
#   MSE: 19065.70
#   MAE: 85.07
#   RMSE: 138.08
#   MAPE: 18.56%
#   RMSPE: 26.26%
#   R^2: 0.66
# Dataset 8, Value 8.0:
#   MSE: 141182.74
#   MAE: 249.28
#   RMSE: 375.74
#   MAPE: 28.43%
#   RMSPE: 46.33%
#   R^2: 0.63
#
# Overall Metrics for Dataset 8:
#   MSE: 97735.70
#   MAE: 203.03
#   RMSE: 312.63
#   MAPE: 22.74%
#   RMSPE: 33.90%
#   R^2: 0.78
#   Percentage within 10%: 35.03%
#   Percentage within 50%: 90.24%
#   Percentage within 100%: 98.22%
# Dataset 9, Value 1.0:
#   MSE: 145112.52
#   MAE: 266.06
#   RMSE: 380.94
#   MAPE: 23.32%
#   RMSPE: 34.53%
#   R^2: 0.74
# Dataset 9, Value 2.0:
#   MSE: 487650.00
#   MAE: 549.60
#   RMSE: 698.32
#   MAPE: 71.65%
#   RMSPE: 100.59%
#   R^2: -2.41
# Dataset 9, Value 3.0:
#   MSE: 103021.07
#   MAE: 214.78
#   RMSE: 320.97
#   MAPE: 25.65%
#   RMSPE: 42.28%
#   R^2: 0.72
# Dataset 9, Value 4.0:
#   MSE: 141771.27
#   MAE: 275.01
#   RMSE: 376.53
#   MAPE: 26.02%
#   RMSPE: 38.70%
#   R^2: 0.69
# Dataset 9, Value 5.0:
#   MSE: 68975.75
#   MAE: 170.44
#   RMSE: 262.63
#   MAPE: 21.55%
#   RMSPE: 30.12%
#   R^2: 0.66
# Dataset 9, Value 6.0:
#   MSE: 202358.38
#   MAE: 296.11
#   RMSE: 449.84
#   MAPE: 33.95%
#   RMSPE: 59.22%
#   R^2: 0.48
# Dataset 9, Value 7.0:
#   MSE: 23349.15
#   MAE: 92.13
#   RMSE: 152.80
#   MAPE: 19.35%
#   RMSPE: 26.91%
#   R^2: 0.67
# Dataset 9, Value 8.0:
#   MSE: 489123.46
#   MAE: 481.21
#   RMSE: 699.37
#   MAPE: 29.17%
#   RMSPE: 35.18%
#   R^2: -0.00
# Skipping value 9.0 for dataset 9 due to empty subset.
#
# Overall Metrics for Dataset 9:
#   MSE: 97919.03
#   MAE: 205.08
#   RMSE: 312.92
#   MAPE: 22.92%
#   RMSPE: 33.75%
#   R^2: 0.78
#   Percentage within 10%: 34.30%
#   Percentage within 50%: 90.25%
#   Percentage within 100%: 98.17%
# Dataset 10, Value 1.0:
#   MSE: 77773.62
#   MAE: 184.52
#   RMSE: 278.88
#   MAPE: 34.57%
#   RMSPE: 54.76%
#   R^2: 0.03
# Dataset 10, Value 2.0:
#   MSE: 144127.25
#   MAE: 275.10
#   RMSE: 379.64
#   MAPE: 25.61%
#   RMSPE: 39.42%
#   R^2: 0.69
# Dataset 10, Value 3.0:
#   MSE: 57240.27
#   MAE: 148.67
#   RMSE: 239.25
#   MAPE: 21.16%
#   RMSPE: 30.09%
#   R^2: 0.69
# Skipping value 4.0 for dataset 10 due to empty subset.
# Dataset 10, Value 5.0:
#   MSE: 389504.17
#   MAE: 461.42
#   RMSE: 624.10
#   MAPE: 63.71%
#   RMSPE: 92.83%
#   R^2: -1.73
# Dataset 10, Value 6.0:
#   MSE: 21040.72
#   MAE: 88.87
#   RMSE: 145.05
#   MAPE: 19.31%
#   RMSPE: 27.47%
#   R^2: 0.63
# Dataset 10, Value 7.0:
#   MSE: 133395.92
#   MAE: 241.76
#   RMSE: 365.23
#   MAPE: 27.70%
#   RMSPE: 44.98%
#   R^2: 0.65
# Dataset 10, Value 8.0:
#   MSE: 115066.00
#   MAE: 216.76
#   RMSE: 339.21
#   MAPE: 23.21%
#   RMSPE: 33.72%
#   R^2: 0.63
# Dataset 10, Value 9.0:
#   MSE: 148265.77
#   MAE: 270.75
#   RMSE: 385.05
#   MAPE: 23.97%
#   RMSPE: 36.75%
#   R^2: 0.74
# Dataset 10, Value 10.0:
#   MSE: 201872.43
#   MAE: 293.83
#   RMSE: 449.30
#   MAPE: 27.72%
#   RMSPE: 48.01%
#   R^2: 0.49
#
# Overall Metrics for Dataset 10:
#   MSE: 98546.54
#   MAE: 203.06
#   RMSE: 313.92
#   MAPE: 22.93%
#   RMSPE: 34.54%
#   R^2: 0.78
#   Percentage within 10%: 35.51%
#   Percentage within 50%: 90.12%
#   Percentage within 100%: 98.06%
# Dataset 11, Value 1.0:
#   MSE: 141414.38
#   MAE: 251.50
#   RMSE: 376.05
#   MAPE: 27.67%
#   RMSPE: 42.62%
#   R^2: 0.67
# Dataset 11, Value 2.0:
#   MSE: 35354.29
#   MAE: 104.84
#   RMSE: 188.03
#   MAPE: 19.06%
#   RMSPE: 28.43%
#   R^2: 0.74
# Dataset 11, Value 3.0:
#   MSE: 125897.11
#   MAE: 234.65
#   RMSE: 354.82
#   MAPE: 23.70%
#   RMSPE: 35.04%
#   R^2: 0.65
# Dataset 11, Value 4.0:
#   MSE: 119778.17
#   MAE: 220.73
#   RMSE: 346.09
#   MAPE: 38.99%
#   RMSPE: 69.57%
#   R^2: -0.41
# Dataset 11, Value 5.0:
#   MSE: 134074.04
#   MAE: 262.24
#   RMSE: 366.16
#   MAPE: 24.30%
#   RMSPE: 35.07%
#   R^2: 0.73
# Dataset 11, Value 6.0:
#   MSE: 126169.31
#   MAE: 251.87
#   RMSE: 355.20
#   MAPE: 25.90%
#   RMSPE: 36.46%
#   R^2: 0.33
# Skipping value 7.0 for dataset 11 due to empty subset.
# Dataset 11, Value 8.0:
#   MSE: 542559.24
#   MAE: 557.55
#   RMSE: 736.59
#   MAPE: 73.22%
#   RMSPE: 107.64%
#   R^2: -2.80
# Dataset 11, Value 9.0:
#   MSE: 39618.13
#   MAE: 120.40
#   RMSE: 199.04
#   MAPE: 21.37%
#   RMSPE: 30.37%
#   R^2: 0.67
# Dataset 11, Value 10.0:
#   MSE: 220264.85
#   MAE: 306.46
#   RMSE: 469.32
#   MAPE: 27.22%
#   RMSPE: 41.88%
#   R^2: 0.50
# Dataset 11, Value 11.0:
#   MSE: 210694.09
#   MAE: 331.11
#   RMSE: 459.01
#   MAPE: 30.63%
#   RMSPE: 44.26%
#   R^2: 0.50
#
# Overall Metrics for Dataset 11:
#   MSE: 100639.91
#   MAE: 207.89
#   RMSE: 317.24
#   MAPE: 23.14%
#   RMSPE: 33.84%
#   R^2: 0.77
#   Percentage within 10%: 34.13%
#   Percentage within 50%: 89.58%
#   Percentage within 100%: 98.19%
# Dataset 12, Value 1.0:
#   MSE: 120860.00
#   MAE: 242.24
#   RMSE: 347.65
#   MAPE: 28.19%
#   RMSPE: 47.95%
#   R^2: 0.69
# Dataset 12, Value 2.0:
#   MSE: 140630.43
#   MAE: 276.02
#   RMSE: 375.01
#   MAPE: 25.60%
#   RMSPE: 38.51%
#   R^2: 0.70
# Dataset 12, Value 3.0:
#   MSE: 489123.46
#   MAE: 481.21
#   RMSE: 699.37
#   MAPE: 29.17%
#   RMSPE: 35.18%
#   R^2: -0.00
# Dataset 12, Value 4.0:
#   MSE: 78570.28
#   MAE: 179.09
#   RMSE: 280.30
#   MAPE: 20.81%
#   RMSPE: 29.40%
#   R^2: 0.69
# Dataset 12, Value 5.0:
#   MSE: 112743.63
#   MAE: 247.41
#   RMSE: 335.77
#   MAPE: 21.00%
#   RMSPE: 27.13%
#   R^2: 0.50
# Dataset 12, Value 6.0:
#   MSE: 24719.14
#   MAE: 90.98
#   RMSE: 157.22
#   MAPE: 17.76%
#   RMSPE: 25.59%
#   R^2: 0.74
# Dataset 12, Value 7.0:
#   MSE: 166642.54
#   MAE: 273.89
#   RMSE: 408.22
#   MAPE: 33.10%
#   RMSPE: 51.96%
#   R^2: 0.61
# Dataset 12, Value 8.0:
#   MSE: 34806.78
#   MAE: 110.82
#   RMSE: 186.57
#   MAPE: 22.35%
#   RMSPE: 32.49%
#   R^2: 0.60
# Dataset 12, Value 9.0:
#   MSE: 542559.24
#   MAE: 557.55
#   RMSE: 736.59
#   MAPE: 73.22%
#   RMSPE: 107.64%
#   R^2: -2.80
# Dataset 12, Value 10.0:
#   MSE: 163353.51
#   MAE: 244.92
#   RMSE: 404.17
#   MAPE: 26.01%
#   RMSPE: 39.04%
#   R^2: 0.59
# Dataset 12, Value 11.0:
#   MSE: 124293.90
#   MAE: 229.02
#   RMSE: 352.55
#   MAPE: 24.17%
#   RMSPE: 36.28%
#   R^2: 0.62
# Dataset 12, Value 12.0:
#   MSE: 153813.26
#   MAE: 276.03
#   RMSE: 392.19
#   MAPE: 23.95%
#   RMSPE: 36.05%
#   R^2: 0.73
#
# Overall Metrics for Dataset 12:
#   MSE: 99999.23
#   MAE: 204.85
#   RMSE: 316.23
#   MAPE: 22.95%
#   RMSPE: 34.28%
#   R^2: 0.77
#   Percentage within 10%: 35.50%
#   Percentage within 50%: 89.99%
#   Percentage within 100%: 98.14%
# Dataset 13, Value 1.0:
#   MSE: 116280.95
#   MAE: 220.63
#   RMSE: 341.00
#   MAPE: 23.93%
#   RMSPE: 35.19%
#   R^2: 0.63
# Dataset 13, Value 2.0:
#   MSE: 134522.79
#   MAE: 242.84
#   RMSE: 366.77
#   MAPE: 25.03%
#   RMSPE: 36.45%
#   R^2: 0.68
# Dataset 13, Value 3.0:
#   MSE: 144780.46
#   MAE: 265.70
#   RMSE: 380.50
#   MAPE: 23.73%
#   RMSPE: 36.12%
#   R^2: 0.74
# Dataset 13, Value 4.0:
#   MSE: 134049.99
#   MAE: 253.43
#   RMSE: 366.13
#   MAPE: 28.51%
#   RMSPE: 44.97%
#   R^2: 0.68
# Dataset 13, Value 5.0:
#   MSE: 118281.47
#   MAE: 240.25
#   RMSE: 343.92
#   MAPE: 24.43%
#   RMSPE: 36.01%
#   R^2: 0.72
# Skipping value 6.0 for dataset 13 due to empty subset.
# Dataset 13, Value 7.0:
#   MSE: 81225.55
#   MAE: 188.73
#   RMSE: 285.00
#   MAPE: 29.13%
#   RMSPE: 37.12%
#   R^2: 0.12
# Dataset 13, Value 8.0:
#   MSE: 217344.56
#   MAE: 331.86
#   RMSE: 466.20
#   MAPE: 34.34%
#   RMSPE: 54.21%
#   R^2: 0.47
# Dataset 13, Value 9.0:
#   MSE: 136105.74
#   MAE: 280.80
#   RMSE: 368.93
#   MAPE: 26.00%
#   RMSPE: 35.17%
#   R^2: 0.42
# Dataset 13, Value 10.0:
#   MSE: 232877.48
#   MAE: 308.64
#   RMSE: 482.57
#   MAPE: 30.98%
#   RMSPE: 56.24%
#   R^2: 0.50
# Dataset 13, Value 11.0:
#   MSE: 23923.80
#   MAE: 95.87
#   RMSE: 154.67
#   MAPE: 19.26%
#   RMSPE: 26.76%
#   R^2: 0.70
# Dataset 13, Value 12.0:
#   MSE: 342757.53
#   MAE: 466.90
#   RMSE: 585.45
#   MAPE: 60.70%
#   RMSPE: 82.87%
#   R^2: -1.40
# Skipping value 13.0 for dataset 13 due to empty subset.
#
# Overall Metrics for Dataset 13:
#   MSE: 99867.85
#   MAE: 205.91
#   RMSE: 316.02
#   MAPE: 23.01%
#   RMSPE: 34.16%
#   R^2: 0.77
#   Percentage within 10%: 34.89%
#   Percentage within 50%: 89.90%
#   Percentage within 100%: 98.20%
# Dataset 14, Value 1.0:
#   MSE: 117780.56
#   MAE: 231.08
#   RMSE: 343.19
#   MAPE: 27.24%
#   RMSPE: 44.58%
#   R^2: 0.68
# Dataset 14, Value 2.0:
#   MSE: 116361.10
#   MAE: 223.97
#   RMSE: 341.12
#   MAPE: 23.94%
#   RMSPE: 35.03%
#   R^2: 0.63
# Dataset 14, Value 3.0:
#   MSE: 147473.98
#   MAE: 270.28
#   RMSE: 384.02
#   MAPE: 23.56%
#   RMSPE: 35.65%
#   R^2: 0.73
# Dataset 14, Value 4.0:
#   MSE: 37063.27
#   MAE: 120.29
#   RMSE: 192.52
#   MAPE: 21.91%
#   RMSPE: 31.19%
#   R^2: 0.68
# Dataset 14, Value 5.0:
#   MSE: 207453.42
#   MAE: 300.18
#   RMSE: 455.47
#   MAPE: 26.80%
#   RMSPE: 42.91%
#   R^2: 0.47
# Dataset 14, Value 6.0:
#   MSE: 85795.46
#   MAE: 205.96
#   RMSE: 292.91
#   MAPE: 39.28%
#   RMSPE: 61.04%
#   R^2: 0.06
# Skipping value 7.0 for dataset 14 due to empty subset.
# Dataset 14, Value 8.0:
#   MSE: 128721.41
#   MAE: 254.27
#   RMSE: 358.78
#   MAPE: 24.47%
#   RMSPE: 36.03%
#   R^2: 0.70
# Skipping value 9.0 for dataset 14 due to empty subset.
# Dataset 14, Value 10.0:
#   MSE: 489123.46
#   MAE: 481.21
#   RMSE: 699.37
#   MAPE: 29.17%
#   RMSPE: 35.18%
#   R^2: -0.00
# Dataset 14, Value 11.0:
#   MSE: 342757.53
#   MAE: 466.90
#   RMSE: 585.45
#   MAPE: 60.70%
#   RMSPE: 82.87%
#   R^2: -1.40
# Skipping value 12.0 for dataset 14 due to empty subset.
# Dataset 14, Value 13.0:
#   MSE: 25825.18
#   MAE: 93.72
#   RMSE: 160.70
#   MAPE: 18.30%
#   RMSPE: 26.14%
#   R^2: 0.73
# Dataset 14, Value 14.0:
#   MSE: 195078.85
#   MAE: 331.52
#   RMSE: 441.68
#   MAPE: 30.79%
#   RMSPE: 43.02%
#   R^2: 0.54
#
# Overall Metrics for Dataset 14:
#   MSE: 99124.27
#   MAE: 205.52
#   RMSE: 314.84
#   MAPE: 23.15%
#   RMSPE: 34.26%
#   R^2: 0.78
#   Percentage within 10%: 34.75%
#   Percentage within 50%: 89.97%
#   Percentage within 100%: 98.09%
# Dataset 15, Value 2.0:
#   MSE: 126937.84
#   MAE: 261.25
#   RMSE: 356.28
#   MAPE: 35.96%
#   RMSPE: 56.03%
#   R^2: 0.44
# Dataset 15, Value 3.0:
#   MSE: 1280494.19
#   MAE: 955.36
#   RMSE: 1131.59
#   MAPE: 147.76%
#   RMSPE: 199.03%
#   R^2: -19.30
# Dataset 15, Value 4.0:
#   MSE: 475734.21
#   MAE: 508.62
#   RMSE: 689.73
#   MAPE: 38.40%
#   RMSPE: 45.72%
#   R^2: -0.14
# Dataset 15, Value 6.0:
#   MSE: 133770.30
#   MAE: 259.91
#   RMSE: 365.75
#   MAPE: 24.71%
#   RMSPE: 35.00%
#   R^2: 0.70
# Dataset 15, Value 7.0:
#   MSE: 297282.64
#   MAE: 401.17
#   RMSE: 545.24
#   MAPE: 37.92%
#   RMSPE: 50.82%
#   R^2: 0.01
# Dataset 15, Value 8.0:
#   MSE: 83674.41
#   MAE: 172.88
#   RMSE: 289.27
#   MAPE: 29.27%
#   RMSPE: 35.65%
#   R^2: -0.48
# Dataset 15, Value 9.0:
#   MSE: 454954.37
#   MAE: 474.20
#   RMSE: 674.50
#   MAPE: 30.16%
#   RMSPE: 35.77%
#   R^2: 0.02
# Dataset 15, Value 12.0:
#   MSE: 523530.67
#   MAE: 508.43
#   RMSE: 723.55
#   MAPE: 50.68%
#   RMSPE: 74.44%
#   R^2: -0.33
# Skipping value 14.0 for dataset 15 due to empty subset.
# Dataset 15, Value 15.0:
#   MSE: 56146.34
#   MAE: 146.86
#   RMSE: 236.95
#   MAPE: 23.71%
#   RMSPE: 33.60%
#   R^2: 0.78
#
# Overall Metrics for Dataset 15:
#   MSE: 115272.42
#   MAE: 224.89
#   RMSE: 339.52
#   MAPE: 25.00%
#   RMSPE: 36.08%
#   R^2: 0.74
#   Percentage within 10%: 29.96%
#   Percentage within 50%: 88.47%
#   Percentage within 100%: 98.00%
